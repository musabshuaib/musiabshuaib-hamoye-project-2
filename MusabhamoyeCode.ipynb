# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\user\Downloads\energydata_complete.csv")

df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
# Checking for Duplicate values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
df = df.drop(columns=['date', 'lights'])

# %%
X = df[['T2']]
y = df['T6']

# %%
from sklearn.linear_model import LinearRegression

# %%
#creating an instance of Linear Regression 
lr = LinearRegression()

# %%
# Training the algorithm
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
lr.score(X, y)
# Out:
# 0.6418990830855493

# %%
# Making predictions
predictions = lr.predict(X)

# %%
from sklearn.metrics import mean_squared_error

rmse = np.sqrt(mean_squared_error(y, predictions))

# Print result 
print("Root Mean Squared Error:", rmse)
# Out:
# Root Mean Squared Error: 3.6444644873484573

# %%
df.columns
# Out:
# Index(['Appliances', 'T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3', 'T4', 'RH_4',
#        'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8', 'RH_8', 'T9', 'RH_9',
#        'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed', 'Visibility',
#        'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
# Define features and target
X = df.drop(columns="Appliances")
y = df["Appliances"]

# %%
from sklearn.model_selection import train_test_split

# Train-test split (70-30)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import MinMaxScaler

# Create an instance of the MinMax scaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
lr = LinearRegression()
lr.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
train_predictions = lr.predict(X_train_scaled)

# %%
from sklearn.metrics import mean_absolute_error

# Calculating the Mean Absolute Error 
mae = mean_absolute_error(y_train, train_predictions)
print("Mean Absolute Error (Training Set):", mae)
# Out:
# Mean Absolute Error (Training Set): 53.742281074934525

# %%
#Calculating the RMSE for the train data 
rmse_train = np.sqrt(mean_squared_error(y_train, train_predictions))
print("Training RMSE:", rmse_train)
# Out:
# Training RMSE: 95.21565985214606

# %%
from sklearn.metrics import mean_absolute_error

# Prediction on the test set
test_predictions = lr.predict(X_test_scaled)

# %%
# Calculating the Mean Absolute Error for test data
mae_test = mean_absolute_error(y_test, test_predictions)

print("Mean Absolute Error for the test set:", mae_test)
# Out:
# Mean Absolute Error for the test set: 53.64297765584956

# %%
# Calculating the Root mean squared error for test data to 3 D.P
rmse_test = np.sqrt(mean_squared_error(y_test, test_predictions))
print("Test RMSE:", rmse_test)
# Out:
# Test RMSE: 93.64046093998029

# %%
#checking for overfitting
from sklearn.metrics import r2_score

r2_train = r2_score(y_train, train_predictions)
r2_test = r2_score(y_test, test_predictions)

print("Train R² Score:", r2_train)
print("Test R² Score:", r2_test)
# Out:
# Train R² Score: 0.14471942308518748
# Test R² Score: 0.14890246319303535

# %%
#The R² scores above shows that the Model is Under fitted

# %%
from sklearn.linear_model import Ridge

ridge = Ridge(alpha=1.0)  # default alpha=1.0
ridge.fit(X_train, y_train)

y_pred_test = ridge.predict(X_test)

rmse_test = np.sqrt(mean_squared_error(y_test, y_pred_test))
print("Test RMSE (Ridge):", rmse_test)
# Out:
# Test RMSE (Ridge): 93.64056872280626

# %%
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=1.0)  
lasso.fit(X_train, y_train)

# Getting the coefficients (feature weights)
coefficients = lasso.coef_

# Checking the amount of non-zero weights
non_zero = sum(coeff != 0 for coeff in coefficients)

print("Number of features with non-zero weights:", non_zero)
# Out:
# Number of features with non-zero weights: 21

# %%
# Predictions on test set with lasso
y_pred_test = lasso.predict(X_test)

# Calculating the RMSE
rmse_test = np.sqrt(mean_squared_error(y_test, y_pred_test))
print("Test RMSE (Lasso):", rmse_test)
# Out:
# Test RMSE (Lasso): 93.89249750342366
